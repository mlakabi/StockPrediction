# %% [markdown]
# # Stock Prediction: Predicting Stock Prices Based on News Headlines

# %% [markdown]
# ## Introduction

# %% [markdown]
# Daily News for Stock Market Prediction: Using 8 years daily news headlines to predict stock market movement

# %% [markdown]
# ## The Clients

# %% [markdown]
# * Traders, trading companies, as well as most financial institutions. Even everyday people who invest in stocks would be able to derive some insights from this.
# * Stock prices rising or dropping has a large effect on financial institutions, everyday people, and the economy as a whole.
# * The media in the sense that they have the ability to alter/understand how their naming conventions affect stock prices

# %% [markdown]
# ## The Data

# %% [markdown]
# #### Stock data: Dow Jones Industrial Average (DJIA) is used to "prove the concept". (Range: 2008-08-08 to 2016-07-01)

# %%
from PIL import Image
path = "/Users/leopardx/Desktop/djia.png"
display(Image.open(path))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1832x1174 at 0x1A292CAF60>

# %% [markdown]
# #### News data: Crawled historical news headlines from Reddit WorldNews Channel (/r/worldnews). They are ranked by reddit users' votes, and only the top 25 headlines are considered for a single date. (Range: 2008-06-08 to 2016-07-01)

# %%
from PIL import Image
path = "/Users/leopardx/Desktop/reddit_world_news.png"
display(Image.open(path))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1762x1596 at 0x1A18C657B8>

# %% [markdown]
# ## Data Wrangling

# %%
import numpy as np
import matplotlib.pyplot as plt
import datetime
import pandas as pd
import seaborn as sns
import scipy
from scipy.stats import chisquare
from scipy.stats import chi2_contingency


# %matplotlib inline

# %% [markdown]
# ### Stock Data

# %% [markdown]
# #### Dow Jones Industrial Average (DJIA) - Range: 2008-06-08 to 2016-07-01

# %%
filename='DJIA_table.csv'
djia = pd.read_csv(filename)
djia.head(5)
# Out:
#          Date          Open          High           Low         Close  \
# 0  2016-07-01  17924.240234  18002.380859  17916.910156  17949.369141
# 1  2016-06-30  17712.759766  17930.609375  17711.800781  17929.990234
# 2  2016-06-29  17456.019531  17704.509766  17456.019531  17694.679688
# 3  2016-06-28  17190.509766  17409.720703  17190.509766  17409.720703
# 4  2016-06-27  17355.210938  17355.210938  17063.080078  17140.240234
#
#       Volume     Adj Close
# 0  82160000   17949.369141
# 1  133030000  17929.990234
# 2  106380000  17694.679688
# 3  112190000  17409.720703
# 4  138740000  17140.240234

# %% [markdown]
# #### Convert date column to datetime

# %%
djia['Date'] = pd.to_datetime(djia['Date'])

# %% [markdown]
# #### Check for missing Data

# %%
djia.describe()
# Out:
#                Open          High           Low         Close        Volume  \
# count  1989.000000   1989.000000   1989.000000   1989.000000   1.989000e+03
# mean   13459.116048  13541.303173  13372.931728  13463.032255  1.628110e+08
# std    3143.281634   3136.271725   3150.420934   3144.006996   9.392343e+07
# min    6547.009766   6709.609863   6469.950195   6547.049805   8.410000e+06
# 25%    10907.339844  11000.980469  10824.759766  10913.379883  1.000000e+08
# 50%    13022.049805  13088.110352  12953.129883  13025.580078  1.351700e+08
# 75%    16477.699219  16550.070312  16392.769531  16478.410156  1.926000e+08
# max    18315.060547  18351.359375  18272.560547  18312.390625  6.749200e+08
#
#           Adj Close
# count  1989.000000
# mean   13463.032255
# std    3144.006996
# min    6547.049805
# 25%    10913.379883
# 50%    13025.580078
# 75%    16478.410156
# max    18312.390625

# %%
djia.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1989 entries, 0 to 1988
# Data columns (total 7 columns):
# Date         1989 non-null datetime64[ns]
# Open         1989 non-null float64
# High         1989 non-null float64
# Low          1989 non-null float64
# Close        1989 non-null float64
# Volume       1989 non-null int64
# Adj Close    1989 non-null float64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 108.9 KB

# %% [markdown]
# ### News Data

# %% [markdown]
# #### Crawled historical news headlines from Reddit WorldNews Channel (/r/worldnews). They are ranked by reddit users' votes, and only the top 25 headlines are considered for a single date. (Range: 2008-06-08 to 2016-07-01)

# %%
## Display full dataframe information
pd.set_option('display.max_colwidth', -1)

filename_R='RedditNews.csv'
news = pd.read_csv(filename_R)
news.head(5)
# Out:
#          Date  \
# 0  2016-07-01
# 1  2016-07-01
# 2  2016-07-01
# 3  2016-07-01
# 4  2016-07-01
#
#                                                                                                                                                                                        News
# 0  A 117-year-old woman in Mexico City finally received her birth certificate, and died a few hours later. Trinidad Alvarez Lira had waited years for proof that she had been born in 1898.
# 1  IMF chief backs Athens as permanent Olympic host
# 2  The president of France says if Brexit won, so can Donald Trump
# 3  British Man Who Must Give Police 24 Hours' Notice of Sex Threatens Hunger Strike: The man is the subject of a sexual risk order despite having never been convicted of a crime.
# 4  100+ Nobel laureates urge Greenpeace to stop opposing GMOs

# %%
news.columns
# Out:
# Index(['Date', 'News'], dtype='object')

# %% [markdown]
# #### Check for missing values

# %%
news.describe()
# Out:
#               Date                                                    News
# count   73608       73608
# unique  2943        73537
# top     2008-10-26  Iceland Declares Independence from International Banks
# freq    50          3

# %%
news.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73608 entries, 0 to 73607
# Data columns (total 2 columns):
# Date    73608 non-null object
# News    73608 non-null object
# dtypes: object(2)
# memory usage: 1.1+ MB

# %% [markdown]
# ### Combined Dataset (World News & DJIA)

# %%
## Display full dataframe information
pd.set_option('display.max_colwidth', -1)
filename_C='Combined_News_DJIA.csv'
combined = pd.read_csv(filename_C)

# %% [markdown]
# The Label variable will be a 1 if the DJIA stayed the same or rose on that date or 0 if the DJIA fell on that date.

# %%
combined.head(2)
# Out:
#          Date  Label  \
# 0  2008-08-08  0
# 1  2008-08-11  1
#
#                                                                                             Top1  \
# 0  b"Georgia 'downs two Russian warplanes' as countries move to brink of war"
# 1  b'Why wont America and Nato help us? If they wont help us now, why did we help them in Iraq?'
#
#                                           Top2  \
# 0  b'BREAKING: Musharraf to be impeached.'
# 1  b'Bush puts foot down on Georgian conflict'
#
#                                                                                           Top3  \
# 0  b'Russia Today: Columns of troops roll into South Ossetia; footage from fighting (YouTube)'
# 1  b"Jewish Georgian minister: Thanks to Israeli training, we're fending off Russia "
#
#                                                                                                                                           Top4  \
# ...

# %%
combined.columns
# Out:
# Index(['Date', 'Label', 'Top1', 'Top2', 'Top3', 'Top4', 'Top5', 'Top6', 'Top7',
#        'Top8', 'Top9', 'Top10', 'Top11', 'Top12', 'Top13', 'Top14', 'Top15',
#        'Top16', 'Top17', 'Top18', 'Top19', 'Top20', 'Top21', 'Top22', 'Top23',
#        'Top24', 'Top25'],
#       dtype='object')

# %% [markdown]
# #### Check for missing values

# %%
combined.describe()
# Out:
#              Label
# count  1989.000000
# mean   0.535445
# std    0.498867
# min    0.000000
# 25%    0.000000
# 50%    1.000000
# 75%    1.000000
# max    1.000000

# %%
combined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1989 entries, 0 to 1988
# Data columns (total 27 columns):
# Date     1989 non-null object
# Label    1989 non-null int64
# Top1     1989 non-null object
# Top2     1989 non-null object
# Top3     1989 non-null object
# Top4     1989 non-null object
# Top5     1989 non-null object
# Top6     1989 non-null object
# Top7     1989 non-null object
# Top8     1989 non-null object
# Top9     1989 non-null object
# Top10    1989 non-null object
# Top11    1989 non-null object
# Top12    1989 non-null object
# Top13    1989 non-null object
# Top14    1989 non-null object
# Top15    1989 non-null object
# Top16    1989 non-null object
# Top17    1989 non-null object
# Top18    1989 non-null object
# Top19    1989 non-null object
# Top20    1989 non-null object
# Top21    1989 non-null object
# Top22    1989 non-null object
# Top23    1988 non-null object
# Top24    1986 non-null object
# Top25    1986 non-null object
# ...

# %% [markdown]
# ##  Data Visualization & Preliminary Data Analysis

# %% [markdown]
# ### Opening Prices

# %%
from matplotlib.pyplot import figure
figure(num=None, figsize=(10, 6), dpi=80, facecolor='w', edgecolor='k')
open_price = plt.plot(djia.Date, djia.Close)
plt.xlabel("Year")
plt.ylabel("Price")
plt.title("Close")
plt.grid(True, alpha = 0.4)

# %%
### DJIA has rallied since 2008 (The economy was in a recession at the time)

# %% [markdown]
# ### Volume

# %%
figure(num=None, figsize=(15, 10), dpi=80, facecolor='w', edgecolor='k')
open = plt.plot(djia.Date, djia.Volume, 'g', alpha = 0.6)
plt.xlabel("Year")
plt.ylabel("Quantity")
plt.title("Volume")
plt.grid(True, alpha = 0.4)

# %% [markdown]
# ### Difference Between Opening & Closing Price

# %%
figure(num=None, figsize=(15, 15), dpi=80, facecolor='w', edgecolor='k')
diff_open_close = (djia.Open-djia.Close)
plt.plot( djia.Date, diff_open_close, alpha = 0.5)
plt.xlabel("Year")
plt.ylabel("Difference in price")
plt.title("Difference between Opening and Closing Price")
plt.grid(True, alpha = 0.4)

# %%
## Every 4 years we can that the markets are very volitile (2008,2012,2016), 2008 was the most volitle (Economy)

# %% [markdown]
# ### Interactive Candlestick Chart

# %% [markdown]
# A candlestick chart is a style of financial chart used to describe price movements of a security, derivative, or currency. Each "candlestick" typically shows one day and is the combination of a line-chart and bar-chart: each bar represents all four important pieces of information for that day: The open, the close, the high and the low.

# %%
import plotly 
plotly.tools.set_credentials_file(username='lakabimanil', api_key='664tEFuijYoffDbLftZn')
import plotly.plotly as py
import plotly.graph_objs as go
from datetime import datetime



trace = go.Ohlc( x=djia['Date'],
                open=djia['Open'],
                high=djia['High'],
                low=djia['Low'],
                close=djia['Close'])
data = [trace]


layout = {
    'title': 'DJIA Interactive Chart',
    'yaxis': {'title': 'DJIA Average Price'}}
    
fig = dict(data=data, layout=layout)
py.iplot(fig, filename='Djia_candlestick')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~lakabimanil/4.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# ### Moving Averages

# %% [markdown]
# A moving average (MA) is a widely used indicator in technical analysis that helps smooth out price action by filtering out the “noise” from random price fluctuations. It is a trend-following, or lagging, indicator because it is based on past prices.

# %%
## https://stackoverflow.com/questions/40060842/moving-average-pandas

# %%
djia['MA'] = djia.Close.rolling(window=5).mean()
#djia['MA']

# %%
from matplotlib.pyplot import figure
figure(num=None, figsize=(10, 6), dpi=80, facecolor='w', edgecolor='k')
open_price = plt.plot(djia.Date, djia.MA)
plt.xlabel("Year")
plt.ylabel("Price")
plt.title("Moving Average")
plt.grid(True, alpha = 0.4)

# %% [markdown]
# ## Inferential Statistics

# %%
## Check time intervals stock price going up/down beginning end of month
## Check percentage and trends with Label. Fraction of 1's and 0's, trends with 1 and 0
## Aggregate the average sentiment (polarity score) across data samples where stock price went down compare the difference using t/z test

# %%
count = len(combined.Label)


count_zero= combined.loc[combined['Label'] == 0]
number_of_zeros= len(count_zero)

count_one = combined.loc[combined['Label'] == 1]
number_of_ones = len(count_one)

print(' Total amount of values:' ,  count,"\n",'Total number of times DJIA rose or stayed the same: ', 
      number_of_ones, "\n", "Total number of times DJIA fell", number_of_zeros)
# Out:
#  Total amount of values: 1989
#  Total number of times DJIA rose or stayed the same:  1065
#  Total number of times DJIA fell 924

# %%
g = sns.countplot(combined.Label).set_title('Number of times DJIA Rose vs Fell')

# %%
figure(num=None, figsize=(10, 6), dpi=80, facecolor='w', edgecolor='k')
numbers =  [number_of_ones, number_of_zeros]
explode = (0, 0.05)
labels= ['DJIA Rose/Stayed Same', 'DJIA Fell']
plt.pie(numbers, explode =explode, labels = labels, autopct='%1.1f%%', shadow=True, startangle=90)
plt.axis('equal')
plt.title('Number of times DJIA Rose vs Fell')
# Out:
# Text(0.5,1,'Number of times DJIA Rose vs Fell')

# %% [markdown]
# ### DJIA Prices at the Beginning & the End of the month

# %%
beginning_of_month = djia[djia.Date.dt.day == 31]
end_of_month =  djia[djia.Date.dt.day == 1]
from matplotlib.pyplot import figure
figure(num=None, figsize=(10, 6), dpi=80, facecolor='w', edgecolor='k')
beginning = plt.plot(beginning_of_month.Date, beginning_of_month.Close)
end = plt.plot(end_of_month.Date,end_of_month.Close)

plt.xlabel("Year")
plt.ylabel("Price")
plt.title("Beginning of the Month VS End of the Month (Closing)")
plt.grid(True, alpha = 0.4)
plt.legend(['Beginning', 'End'])

# %%
## End of the month seems to be far more volitile then the begining of the month

# %% [markdown]
# ## Machine Learning

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# ### Split Training and Test Data

# %%
train = combined[combined['Date'] < '2015-01-01']
test = combined[combined['Date'] > '2014-12-31']

# %% [markdown]
# ### Text Preprocessing

# %%
test
# Out:
#             Date  Label  \
# 1611  2015-01-02  1
# 1612  2015-01-05  0
# 1613  2015-01-06  0
# 1614  2015-01-07  1
# 1615  2015-01-08  1
# 1616  2015-01-09  0
# 1617  2015-01-12  0
# 1618  2015-01-13  0
# 1619  2015-01-14  0
# 1620  2015-01-15  0
# 1621  2015-01-16  1
# 1622  2015-01-20  1
# 1623  2015-01-21  1
# 1624  2015-01-22  1
# 1625  2015-01-23  0
# 1626  2015-01-26  1
# 1627  2015-01-27  0
# 1628  2015-01-28  0
# 1629  2015-01-29  1
# 1630  2015-01-30  0
# 1631  2015-02-02  1
# 1632  2015-02-03  1
# 1633  2015-02-04  1
# 1634  2015-02-05  1
# 1635  2015-02-06  0
# 1636  2015-02-09  0
# 1637  2015-02-10  1
# 1638  2015-02-11  0
# 1639  2015-02-12  1
# 1640  2015-02-13  1
# ...          ... ..
# 1959  2016-05-20  1
# 1960  2016-05-23  0
# 1961  2016-05-24  1
# 1962  2016-05-25  1
# 1963  2016-05-26  0
# 1964  2016-05-27  1
# 1965  2016-05-31  0
# 1966  2016-06-01  1
# 1967  2016-06-02  1
# 1968  2016-06-03  0
# 1969  2016-06-06  1
# 1970  2016-06-07  1
# 1971  2016-06-08  1
# ...

# %%
## Combine all headlines together(Bag of Words representation), use scikit learn for preprecosseing (Stop words, stem, Count Vecotrize)
# Out:
# (1611, 31675)
